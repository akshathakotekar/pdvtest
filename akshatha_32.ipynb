# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=df=pd.read_csv('/home/msois/Downloads/milk_production(2).csv')
df.head()
# Out:
#   Category     State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 0    State     Andhra Pradesh            3102.0            3377.0
# 1    State  Arunachal Pradesh              28.0              22.0
# 2    State              Assam             666.0             658.0
# 3    State              Bihar            3561.0            3661.0
# 4    State       Chhattisgarh             644.0             701.0
#
#    Cow Milk-2013-14  Cow Milk-2014-15  Cow Milk-2015-16  Boffalo Milk-2010-11  \
# 0            3799.0              3079              3369                8101.0
# 1              43.0                46                50                   NaN
# 2             677.0               685               703                 101.0
# 3            3986.0              4318              4881                2798.0
# 4             788.0               824               919                 343.0
#
#    Boffalo Milk-2011-12  Boffalo Milk-2013-14  Boffalo Milk-2014-15  \
# ...

# %%
df=df.fillna(0)

# %%
df['totalmilk']=df["Cow Milk-2013-14"] + df["Boffalo Milk-2013-14"] + df["Goat Milk-2013-14"]
df
# Out:
#            Category        State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 0             State        Andhra Pradesh            3102.0            3377.0
# 1             State     Arunachal Pradesh              28.0              22.0
# 2             State                 Assam             666.0             658.0
# 3             State                 Bihar            3561.0            3661.0
# 4             State          Chhattisgarh             644.0             701.0
# 5             State                   Goa              37.0              42.0
# 6             State               Gujarat            3572.0            3848.0
# 7             State               Haryana             966.0             998.0
# 8             State      Himachal Pradesh             669.0             680.0
# 9             State       Jammu & Kashmir            1205.0            1204.0
# 10            State             Jharkhand             842.0            1017.0
# ...

# %%
milk=df[['State/ UT Name','totalmilk']]
milk
# Out:
#           State/ UT Name  totalmilk
# 0         Andhra Pradesh    13007.0
# 1      Arunachal Pradesh       43.0
# 2                  Assam      814.0
# 3                  Bihar     7197.0
# 4           Chhattisgarh     1208.0
# 5                    Goa       68.0
# 6                Gujarat    11112.0
# 7                Haryana     7442.0
# 8       Himachal Pradesh     1151.0
# 9        Jammu & Kashmir     1615.0
# 10             Jharkhand     1699.0
# 11             Karnataka     5997.0
# 12                Kerala     2654.0
# 13        Madhya Pradesh     9599.0
# 14           Maharashtra     9088.0
# 15               Manipur       82.0
# 16             Meghalaya       82.0
# 17               Mizoram       15.0
# 18              Nagaland       80.0
# 19                Odisha     1861.0
# 20                Punjab    10011.0
# 21             Rajasthan    14573.0
# 22                Sikkim       46.0
# 23            Tamil Nadu     7049.0
# 24             Telangana        0.0
# ...

# %%
milk[milk['totalmilk']==milk['totalmilk'].max()]['State/ UT Name']
# Out:
# 26    Uttar Pradesh
# Name: State/ UT Name, dtype: object

# %%
df["y2011"] =(df["Cow Milk-2010-11"] + df["Boffalo Milk-2010-11"] + df["Goat Milk-2010-11"]).sort_values(ascending=False)
df["y2012"]= df["Cow Milk-2011-12"] + df["Boffalo Milk-2010-11"] + df["Goat Milk-2010-11"]
df["y2014"]= df["Cow Milk-2013-14"] + df["Boffalo Milk-2010-11"] + df["Goat Milk-2010-11"]
df["y2015"]= df["Cow Milk-2014-15"] + df["Boffalo Milk-2010-11"] + df["Goat Milk-2010-11"]

max2011=df.sort_values('y2011',ascending=False)["State/ UT Name"].head()
max2011
# Out:
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 20            Punjab
# 6            Gujarat
# Name: State/ UT Name, dtype: object

# %%
df["y2016"]= df["Cow Milk-2015-16"] + df["Boffalo Milk-2015-16"] + df["Goat Milk-2015-16"]
df[df["y2016"].ge(df["y2015"]) & df["y2015"].ge(df["y2014"])].head()
# Out:
#   Category     State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 1    State  Arunachal Pradesh              28.0              22.0
# 2    State              Assam             666.0             658.0
# 3    State              Bihar            3561.0            3661.0
# 4    State       Chhattisgarh             644.0             701.0
# 6    State            Gujarat            3572.0            3848.0
#
#    Cow Milk-2013-14  Cow Milk-2014-15  Cow Milk-2015-16  Boffalo Milk-2010-11  \
# 1              43.0                46                50                   0.0
# 2             677.0               685               703                 101.0
# 3            3986.0              4318              4881                2798.0
# 4             788.0               824               919                 343.0
# 6            4673.0              4999              5461                5514.0
#
#    Boffalo Milk-2011-12  Boffalo Milk-2013-14  ...    Goat Milk-2011-12  \
# ...

# %%
year=[2010,2011,2012,2013,2014,2015]
pop_totalmilk[]
# Out:
#   File "<ipython-input-138-d9f7822b4a00>", line 2
#     pop_totalmilk[]
#                   ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("oil_reserves.csv")
df.head()
# Out:
#                Region Country/ Region     2010     2011     2012     2013  \
# 0       North America              US   34.990   39.775   44.180   48.463
# 1       North America          Canada  174.848  174.177  173.716  173.038
# 2       North America          Mexico   11.691   11.394   11.424   11.079
# 3  S. & Cent. America       Argentina    2.524    2.525    2.354    2.330
# 4  S. & Cent. America          Brazil   14.246   15.050   15.314   15.593
#
#       2014     2015     2016
# 0   54.962   47.987   47.987
# 1  172.156  171.512  171.512
# 2   10.816    7.977    7.977
# 3    2.380    2.395    2.395
# 4   16.184   13.000   12.634

# %%
total=df["2014"]+df["2015"]+df["2016"]
print(total.max())
a=np.where(total==total.max())
new=df.iloc[a]
new["Country/ Region"]
# Out:
# 901.809
# 9    Venezuela
# Name: Country/ Region, dtype: object

# %%
df["totaloil"]=df["2014"]+df["2015"]+df["2016"]+df["2012"]+df["2013"]+df["2010"]+df["2011"]

# %%
df[df["totaloil"].max() and df["Region"]=="North America"]
# Out:
#           Region Country/ Region     2010     2011     2012     2013     2014  \
# 0  North America              US   34.990   39.775   44.180   48.463   54.962
# 1  North America          Canada  174.848  174.177  173.716  173.038  172.156
# 2  North America          Mexico   11.691   11.394   11.424   11.079   10.816
#
#       2015     2016  oil_allyear  totaloil
# 0   47.987   47.987      318.344   318.344
# 1  171.512  171.512     1210.959  1210.959
# 2    7.977    7.977       72.358    72.358

# %%
print(df[df['Region']==df['totaloil'].max()])
# Out:
# Empty DataFrame
# Columns: [Region, Country/ Region, 2010, 2011, 2012, 2013, 2014, 2015, 2016, oil_allyear, totaloil]
# Index: []

# %%
print(df.sort_values('2015',ascending=False)["Country/ Region"].head())
# Out:
# 9        Venezuela
# 27    Saudi Arabia
# 1           Canada
# 22            Iran
# 23            Iraq
# Name: Country/ Region, dtype: object
